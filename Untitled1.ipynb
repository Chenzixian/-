# %%
from sklearn.linear_model import LinearRegression#导入线性回归模型
import matplotlib.pyplot as plt #绘图库
import numpy as np

# %%
#构建房价数据并可视化

x = np.array([121,125,131,141,152,161,111,167,173,188,193,166]).reshape(-1,1)#x是房层面积，作为特征
y = np.array([300,350,425,405,496,517,270,530,164,745,824,521])#y是房价
plt.scatter(x,y)
plt.xlabel("area")#添加横坐标面积
plt.ylabel("price")#添加纵坐标价格
plt.show()

# %%
#训练模型
lr = LinearRegression()#将线性回归模型封装为对象
lr.fit(x,y)#模型在数据上训练
# Out:
# LinearRegression()

# %%
#可视化
w = lr.coef_#存储模型的斜率
b = lr.intercept_#存储模型的截距
print('斜率:',w)
print('截距:',b)
# Out:
# 斜率: [4.98467124]
# 截距: -274.8769665187576

# %%
plt.scatter(x,y)
plt.xlabel("area")#添加横坐标面积
plt.ylabel("price")#添加纵坐标价格
plt.plot([x[0],x[-1]],[x[0]*w+b,x[-1]*w+b])

# %%
testX = np.array([[自己输入]])#测试样本，面积为自己输入
lr.predict(testX)
# Out:
# array([373.13029447])
